# %%
# 从同目录的 python_environment_check.py 导入两个函数：
#   get_requirements_dict() —— 解析 requirements.txt，得到「包名 -> 版本约束」字典
#   check_packages()        —— 逐一比对已安装版本是否满足约束，打印 [OK]/[FAIL]
from python_environment_check import check_packages, get_requirements_dict

d = get_requirements_dict()   # 读取本项目的依赖版本要求
check_packages(d)             # 检查当前环境是否达标（运行前的环境自检）
